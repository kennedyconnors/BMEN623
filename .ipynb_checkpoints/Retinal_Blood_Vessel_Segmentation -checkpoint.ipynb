# %%
from PIL import Image
import matplotlib.pyplot as plt

# Load the fundus images 
image = Image.open('images/diaretdb1_image001.png')

# Display the image
plt.figure(figsize=(6,6))
plt.imshow(image)
plt.axis('off') 
plt.title("Fundus Image - Loaded in Jupyter Notebook")
plt.show()

# %%
# AIM 1: Develop a preprocessing pipeline for retinal fundus images
# Import libraries
import cv2
import matplotlib.pyplot as plt

# Load the original fundus image
img = cv2.imread('images/diaretdb1_image001.png') 
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# Step 1: Convert to grayscale
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# Step 2: Apply Contrast Limited Adaptive Histogram Equalization (CLAHE)
clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8, 8))
clahe_img = clahe.apply(gray)

# Step 3: Apply Gaussian blur for noise reduction
gaussian_blur = cv2.GaussianBlur(clahe_img, (5, 5), 0)

# Display results
titles = ['Original Image', 'Grayscale', 'CLAHE Enhanced', 'Gaussian Blurred']
images = [img_rgb, gray, clahe_img, gaussian_blur]

plt.figure(figsize=(12, 6))
for i in range(4):
    plt.subplot(1, 4, i+1)
    plt.imshow(images[i], cmap='gray' if i != 0 else None)
    plt.title(titles[i])
    plt.axis('off')
plt.tight_layout()
plt.show()

# %%
import cv2
import os

# === Set paths ===
input_folder = 'images/'  # folder with original images
output_folder = 'preprocessed/'

# Create subfolders for preprocessed outputs
os.makedirs(os.path.join(output_folder, 'gray'), exist_ok=True)
os.makedirs(os.path.join(output_folder, 'clahe'), exist_ok=True)
os.makedirs(os.path.join(output_folder, 'blurred'), exist_ok=True)

# === Process each image ===
for filename in os.listdir(input_folder):
    if filename.endswith(('.png', '.jpg', '.jpeg')):
        # Load image
        img_path = os.path.join(input_folder, filename)
        img = cv2.imread(img_path)

        if img is None:
            print(f"Skipped: {filename} (could not read)")
            continue

        # Convert to grayscale
        gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

        # Apply CLAHE
        clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8, 8))
        clahe_img = clahe.apply(gray)

        # Apply Gaussian blur
        blurred = cv2.GaussianBlur(clahe_img, (5, 5), 0)

        # Save outputs
        name, _ = os.path.splitext(filename)
        cv2.imwrite(os.path.join(output_folder, 'gray', f'{name}_gray.png'), gray)
        cv2.imwrite(os.path.join(output_folder, 'clahe', f'{name}_clahe.png'), clahe_img)
        cv2.imwrite(os.path.join(output_folder, 'blurred', f'{name}_blurred.png'), blurred)

        print(f'Processed and saved: {filename}')
# Out:
# Processed and saved: diaretdb1_image074.png
# Processed and saved: diaretdb1_image060.png
# Processed and saved: diaretdb1_image048.png
# Processed and saved: diaretdb1_image049.png
# Processed and saved: diaretdb1_image061.png
# Processed and saved: diaretdb1_image075.png
# Processed and saved: diaretdb1_image088.png
# Processed and saved: diaretdb1_image063.png
# Processed and saved: diaretdb1_image077.png
# Processed and saved: diaretdb1_image076.png
# Processed and saved: diaretdb1_image062.png
# Processed and saved: diaretdb1_image089.png
# Processed and saved: diaretdb1_image066.png
# Processed and saved: diaretdb1_image072.png
# Processed and saved: diaretdb1_image073.png
# Processed and saved: diaretdb1_image067.png
# Processed and saved: diaretdb1_image059.png
# Processed and saved: diaretdb1_image071.png
# Processed and saved: diaretdb1_image065.png
# Processed and saved: diaretdb1_image064.png
# Processed and saved: diaretdb1_image070.png
# Processed and saved: diaretdb1_image058.png
# Processed and saved: diaretdb1_image017.png
# Processed and saved: diaretdb1_image003.png
# Processed and saved: diaretdb1_image002.png
# Processed and saved: diaretdb1_image016.png
# Processed and saved: diaretdb1_image014.png
# Processed and saved: diaretdb1_image028.png
# Processed and saved: diaretdb1_image029.png
# Processed and saved: diaretdb1_image015.png
# Processed and saved: diaretdb1_image001.png
# Processed and saved: diaretdb1_image039.png
# Processed and saved: diaretdb1_image005.png
# Processed and saved: diaretdb1_image011.png
# Processed and saved: diaretdb1_image010.png
# Processed and saved: diaretdb1_image004.png
# Processed and saved: diaretdb1_image038.png
# Processed and saved: diaretdb1_image012.png
# Processed and saved: diaretdb1_image006.png
# Processed and saved: diaretdb1_image007.png
# Processed and saved: diaretdb1_image013.png
# Processed and saved: diaretdb1_image036.png
# Processed and saved: diaretdb1_image022.png
# Processed and saved: diaretdb1_image023.png
# Processed and saved: diaretdb1_image037.png
# Processed and saved: diaretdb1_image021.png
# Processed and saved: diaretdb1_image035.png
# Processed and saved: diaretdb1_image009.png
# Processed and saved: diaretdb1_image008.png
# Processed and saved: diaretdb1_image034.png
# Processed and saved: diaretdb1_image020.png
# Processed and saved: diaretdb1_image018.png
# Processed and saved: diaretdb1_image024.png
# Processed and saved: diaretdb1_image030.png
# Processed and saved: diaretdb1_image031.png
# Processed and saved: diaretdb1_image025.png
# Processed and saved: diaretdb1_image019.png
# Processed and saved: diaretdb1_image033.png
# Processed and saved: diaretdb1_image027.png
# Processed and saved: diaretdb1_image026.png
# Processed and saved: diaretdb1_image032.png
# Processed and saved: diaretdb1_image082.png
# Processed and saved: diaretdb1_image055.png
# Processed and saved: diaretdb1_image041.png
# Processed and saved: diaretdb1_image069.png
# Processed and saved: diaretdb1_image068.png
# Processed and saved: diaretdb1_image040.png
# Processed and saved: diaretdb1_image054.png
# Processed and saved: diaretdb1_image083.png
# Processed and saved: diaretdb1_image081.png
# Processed and saved: diaretdb1_image042.png
# Processed and saved: diaretdb1_image056.png
# Processed and saved: diaretdb1_image057.png
# Processed and saved: diaretdb1_image043.png
# Processed and saved: diaretdb1_image080.png
# Processed and saved: diaretdb1_image084.png
# Processed and saved: diaretdb1_image047.png
# Processed and saved: diaretdb1_image053.png
# Processed and saved: diaretdb1_image052.png
# Processed and saved: diaretdb1_image046.png
# Processed and saved: diaretdb1_image085.png
# Processed and saved: diaretdb1_image087.png
# Processed and saved: diaretdb1_image078.png
# Processed and saved: diaretdb1_image050.png
# Processed and saved: diaretdb1_image044.png
# Processed and saved: diaretdb1_image045.png
# Processed and saved: diaretdb1_image051.png
# Processed and saved: diaretdb1_image079.png
# Processed and saved: diaretdb1_image086.png

# %%
import matplotlib.pyplot as plt

sample_file = os.listdir(input_folder)[0]
img = cv2.imread(os.path.join(input_folder, sample_file))
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
clahe_img = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8,8)).apply(gray)
blurred = cv2.GaussianBlur(clahe_img, (5,5), 0)

# Display
titles = ['Original', 'Grayscale', 'CLAHE', 'Blurred']
images = [cv2.cvtColor(img, cv2.COLOR_BGR2RGB), gray, clahe_img, blurred]

plt.figure(figsize=(12, 4))
for i in range(4):
    plt.subplot(1, 4, i+1)
    plt.imshow(images[i], cmap='gray' if i != 0 else None)
    plt.title(titles[i])
    plt.axis('off')
plt.tight_layout()
plt.show()

# %%
# AIM 2: Implement and refine blood vessel segmentation techniques
import cv2
import os
import numpy as np
from skimage.morphology import skeletonize
from skimage import img_as_bool, img_as_ubyte

# Paths
input_folder = 'preprocessed/blurred/'     # Preprocessed blurred images
output_folder = 'results/segmented/'       # Where you’ll save segmentation output
os.makedirs(output_folder, exist_ok=True)

# Loop through images
for filename in os.listdir(input_folder):
    if filename.endswith('.png') or filename.endswith('.jpg'):
        # Load preprocessed (blurred) image
        img_path = os.path.join(input_folder, filename)
        blurred = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)

        if blurred is None:
            print(f"Could not read: {filename}")
            continue

        # Step 1: Canny Edge Detection
        edges = cv2.Canny(blurred, threshold1=30, threshold2=90)

        # Step 2: Morphological Operations to refine edges
        kernel = np.ones((3, 3), np.uint8)
        morph = cv2.morphologyEx(edges, cv2.MORPH_CLOSE, kernel)
        morph = cv2.morphologyEx(morph, cv2.MORPH_OPEN, kernel)

        # Step 3 (Optional): Skeletonization
        skeleton = skeletonize(img_as_bool(morph))
        skeleton_uint8 = img_as_ubyte(skeleton)

        # Save segmented vessel output
        name, _ = os.path.splitext(filename)
        cv2.imwrite(os.path.join(output_folder, f'{name}_segmented.png'), skeleton_uint8)

        print(f'Segmented and saved: {filename}')
# Out:
# Segmented and saved: diaretdb1_image063_blurred.png
# Segmented and saved: diaretdb1_image013_blurred.png
# Segmented and saved: diaretdb1_image021_blurred.png
# Segmented and saved: diaretdb1_image051_blurred.png
# Segmented and saved: diaretdb1_image082_blurred.png
# Segmented and saved: diaretdb1_image034_blurred.png
# Segmented and saved: diaretdb1_image044_blurred.png
# Segmented and saved: diaretdb1_image058_blurred.png
# Segmented and saved: diaretdb1_image028_blurred.png
# Segmented and saved: diaretdb1_image076_blurred.png
# Segmented and saved: diaretdb1_image006_blurred.png
# Segmented and saved: diaretdb1_image041_blurred.png
# Segmented and saved: diaretdb1_image031_blurred.png
# Segmented and saved: diaretdb1_image003_blurred.png
# Segmented and saved: diaretdb1_image073_blurred.png
# Segmented and saved: diaretdb1_image038_blurred.png
# Segmented and saved: diaretdb1_image048_blurred.png
# Segmented and saved: diaretdb1_image016_blurred.png
# Segmented and saved: diaretdb1_image066_blurred.png
# Segmented and saved: diaretdb1_image087_blurred.png
# Segmented and saved: diaretdb1_image054_blurred.png
# Segmented and saved: diaretdb1_image024_blurred.png
# Segmented and saved: diaretdb1_image057_blurred.png
# Segmented and saved: diaretdb1_image027_blurred.png
# Segmented and saved: diaretdb1_image084_blurred.png
# Segmented and saved: diaretdb1_image079_blurred.png
# Segmented and saved: diaretdb1_image009_blurred.png
# Segmented and saved: diaretdb1_image015_blurred.png
# Segmented and saved: diaretdb1_image065_blurred.png
# Segmented and saved: diaretdb1_image070_blurred.png
# Segmented and saved: diaretdb1_image042_blurred.png
# Segmented and saved: diaretdb1_image032_blurred.png
# Segmented and saved: diaretdb1_image088_blurred.png
# Segmented and saved: diaretdb1_image075_blurred.png
# Segmented and saved: diaretdb1_image005_blurred.png
# Segmented and saved: diaretdb1_image037_blurred.png
# Segmented and saved: diaretdb1_image047_blurred.png
# Segmented and saved: diaretdb1_image019_blurred.png
# Segmented and saved: diaretdb1_image069_blurred.png
# Segmented and saved: diaretdb1_image081_blurred.png
# Segmented and saved: diaretdb1_image022_blurred.png
# Segmented and saved: diaretdb1_image052_blurred.png
# Segmented and saved: diaretdb1_image060_blurred.png
# Segmented and saved: diaretdb1_image010_blurred.png
# Segmented and saved: diaretdb1_image086_blurred.png
# Segmented and saved: diaretdb1_image025_blurred.png
# Segmented and saved: diaretdb1_image055_blurred.png
# Segmented and saved: diaretdb1_image049_blurred.png
# Segmented and saved: diaretdb1_image039_blurred.png
# Segmented and saved: diaretdb1_image067_blurred.png
# Segmented and saved: diaretdb1_image017_blurred.png
# Segmented and saved: diaretdb1_image072_blurred.png
# Segmented and saved: diaretdb1_image002_blurred.png
# Segmented and saved: diaretdb1_image030_blurred.png
# Segmented and saved: diaretdb1_image040_blurred.png
# Segmented and saved: diaretdb1_image029_blurred.png
# Segmented and saved: diaretdb1_image059_blurred.png
# Segmented and saved: diaretdb1_image007_blurred.png
# Segmented and saved: diaretdb1_image077_blurred.png
# Segmented and saved: diaretdb1_image045_blurred.png
# Segmented and saved: diaretdb1_image035_blurred.png
# Segmented and saved: diaretdb1_image050_blurred.png
# Segmented and saved: diaretdb1_image020_blurred.png
# Segmented and saved: diaretdb1_image083_blurred.png
# Segmented and saved: diaretdb1_image012_blurred.png
# Segmented and saved: diaretdb1_image062_blurred.png
# Segmented and saved: diaretdb1_image011_blurred.png
# Segmented and saved: diaretdb1_image061_blurred.png
# Segmented and saved: diaretdb1_image080_blurred.png
# Segmented and saved: diaretdb1_image053_blurred.png
# Segmented and saved: diaretdb1_image023_blurred.png
# Segmented and saved: diaretdb1_image046_blurred.png
# Segmented and saved: diaretdb1_image036_blurred.png
# Segmented and saved: diaretdb1_image068_blurred.png
# Segmented and saved: diaretdb1_image018_blurred.png
# Segmented and saved: diaretdb1_image004_blurred.png
# Segmented and saved: diaretdb1_image074_blurred.png
# Segmented and saved: diaretdb1_image089_blurred.png
# Segmented and saved: diaretdb1_image033_blurred.png
# Segmented and saved: diaretdb1_image043_blurred.png
# Segmented and saved: diaretdb1_image071_blurred.png
# Segmented and saved: diaretdb1_image001_blurred.png
# Segmented and saved: diaretdb1_image064_blurred.png
# Segmented and saved: diaretdb1_image014_blurred.png
# Segmented and saved: diaretdb1_image026_blurred.png
# Segmented and saved: diaretdb1_image056_blurred.png
# Segmented and saved: diaretdb1_image008_blurred.png
# Segmented and saved: diaretdb1_image078_blurred.png
# Segmented and saved: diaretdb1_image085_blurred.png

# %%
for f in os.listdir('results/segmented/'):
    print(f)
# Out:
# diaretdb1_image059_blurred_segmented.png
# diaretdb1_image037_blurred_segmented.png
# diaretdb1_image081_blurred_segmented.png
# diaretdb1_image021_blurred_segmented.png
# diaretdb1_image063_blurred_segmented.png
# diaretdb1_image075_blurred_segmented.png
# diaretdb1_image029_blurred_segmented.png
# diaretdb1_image047_blurred_segmented.png
# diaretdb1_image089_blurred_segmented.png
# diaretdb1_image051_blurred_segmented.png
# diaretdb1_image013_blurred_segmented.png
# diaretdb1_image005_blurred_segmented.png
# diaretdb1_image061_blurred_segmented.png
# diaretdb1_image077_blurred_segmented.png
# diaretdb1_image019_blurred_segmented.png
# diaretdb1_image083_blurred_segmented.png
# diaretdb1_image035_blurred_segmented.png
# diaretdb1_image023_blurred_segmented.png
# diaretdb1_image011_blurred_segmented.png
# diaretdb1_image007_blurred_segmented.png
# diaretdb1_image069_blurred_segmented.png
# diaretdb1_image045_blurred_segmented.png
# diaretdb1_image053_blurred_segmented.png
# diaretdb1_image043_blurred_segmented.png
# diaretdb1_image055_blurred_segmented.png
# diaretdb1_image017_blurred_segmented.png
# diaretdb1_image079_blurred_segmented.png
# diaretdb1_image001_blurred_segmented.png
# diaretdb1_image085_blurred_segmented.png
# diaretdb1_image033_blurred_segmented.png
# diaretdb1_image025_blurred_segmented.png
# diaretdb1_image067_blurred_segmented.png
# diaretdb1_image009_blurred_segmented.png
# diaretdb1_image071_blurred_segmented.png
# diaretdb1_image015_blurred_segmented.png
# diaretdb1_image003_blurred_segmented.png
# diaretdb1_image041_blurred_segmented.png
# diaretdb1_image039_blurred_segmented.png
# diaretdb1_image057_blurred_segmented.png
# diaretdb1_image065_blurred_segmented.png
# diaretdb1_image073_blurred_segmented.png
# diaretdb1_image031_blurred_segmented.png
# diaretdb1_image087_blurred_segmented.png
# diaretdb1_image049_blurred_segmented.png
# diaretdb1_image027_blurred_segmented.png
# diaretdb1_image088_blurred_segmented.png
# diaretdb1_image050_blurred_segmented.png
# diaretdb1_image046_blurred_segmented.png
# diaretdb1_image028_blurred_segmented.png
# diaretdb1_image004_blurred_segmented.png
# diaretdb1_image012_blurred_segmented.png
# diaretdb1_image020_blurred_segmented.png
# diaretdb1_image036_blurred_segmented.png
# diaretdb1_image058_blurred_segmented.png
# diaretdb1_image080_blurred_segmented.png
# diaretdb1_image074_blurred_segmented.png
# diaretdb1_image062_blurred_segmented.png
# diaretdb1_image068_blurred_segmented.png
# diaretdb1_image006_blurred_segmented.png
# diaretdb1_image010_blurred_segmented.png
# diaretdb1_image052_blurred_segmented.png
# diaretdb1_image044_blurred_segmented.png
# diaretdb1_image018_blurred_segmented.png
# diaretdb1_image076_blurred_segmented.png
# diaretdb1_image060_blurred_segmented.png
# diaretdb1_image022_blurred_segmented.png
# diaretdb1_image082_blurred_segmented.png
# diaretdb1_image034_blurred_segmented.png
# diaretdb1_image024_blurred_segmented.png
# diaretdb1_image084_blurred_segmented.png
# diaretdb1_image032_blurred_segmented.png
# diaretdb1_image070_blurred_segmented.png
# diaretdb1_image008_blurred_segmented.png
# diaretdb1_image066_blurred_segmented.png
# diaretdb1_image054_blurred_segmented.png
# diaretdb1_image042_blurred_segmented.png
# diaretdb1_image078_blurred_segmented.png
# diaretdb1_image016_blurred_segmented.png
# diaretdb1_image072_blurred_segmented.png
# diaretdb1_image064_blurred_segmented.png
# diaretdb1_image026_blurred_segmented.png
# diaretdb1_image048_blurred_segmented.png
# diaretdb1_image030_blurred_segmented.png
# diaretdb1_image086_blurred_segmented.png
# diaretdb1_image002_blurred_segmented.png
# diaretdb1_image014_blurred_segmented.png
# diaretdb1_image056_blurred_segmented.png
# diaretdb1_image038_blurred_segmented.png
# diaretdb1_image040_blurred_segmented.png
